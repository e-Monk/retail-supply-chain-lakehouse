# %%
catalog_name = 'olist'
bronze_schema = 'bronze'
silver_schema = 'silver'
gold_schema = 'gold'
logs_schema = 'logs'
my_zone = "Asia/Kolkata"
source_system = 'olist'

# %%
landing_folder_path = "/Volumes/olist/landing/files"
full_logs_table_name = f"{catalog_name}.{logs_schema}.pipeline_logs"
