# %%
catalog_name = 'olist'
bronze_schema = 'bronze'
silver_schema = 'silver'
gold_schema = 'gold'
logs_schema = 'logs'
my_zone = "Asia/Kolkata"
source_system = 'olist'

# %%
landing_folder_path = "/Volumes/olist/landing/files"

processed_folder_path = "/Volumes/olist/processed/files"
duplicates_folder_path = "/Volumes/olist/duplicate/files"
failed_folder_path = "/Volumes/olist/failed/files"

# %%
full_logs_table_name = f"{catalog_name}.{logs_schema}.pipeline_logs"
full_pipeline_control_table_name = f"{catalog_name}.{logs_schema}.pipeline_control"
